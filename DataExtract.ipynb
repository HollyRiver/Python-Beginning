# %%
import requests
import json

# %%
url = "http://211.237.50.150:7080/openapi/sample/xml/Grid_20210806000000000612_1/1/5"

params = {
    "API_KEY" : "aa73f4dd3ea43ccda3061db908847461f48c54dc348e60bba8e1ae89f0a1ae7e",
    "TYPE" : "xml"
}

# %%
requests.get("http://211.237.50.150:7080/openapi/sample/xml/Grid_20210806000000000612_1/1/5", params = )
